# %%
from prepocessing import DataProcessor
from Modello import model
from Training import training
from Testing import testing

# %%
Processor = DataProcessor()
X_train, X_test, y_train, y_test = Processor.get_datas()

# %%
Model=model(num_k=[32,64], k_size=[3,3], p_size=[2,2], num_n=128)
Training=training(model=Model.model,X_train=X_train,y_train=y_train, val_split=0.1, ep=5, b_size=32)
# Out:
# Epoch 1/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.4024 - loss: 1.9836 - val_accuracy: 0.9552 - val_loss: 0.1912
# Epoch 2/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9284 - loss: 0.2288 - val_accuracy: 0.9949 - val_loss: 0.0333
# Epoch 3/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9791 - loss: 0.0743 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 4/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9858 - loss: 0.0484 - val_accuracy: 0.9989 - val_loss: 0.0079
# Epoch 5/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9905 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 9.9284e-04

# %%
Testing=testing(X_test=X_test,y_test=y_test, model=Training.model)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9139 - loss: 0.3425

# %%
predicted_classes, true_classes = Testing.predictions(X_test=X_test,y_test=y_test)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
Testing.confusionmatrix(true_classes, predicted_classes)
